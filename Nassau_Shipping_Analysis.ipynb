# %%
import pandas as pd

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'nassau.csv', 'Nassau_Shipping_Analysis.ipynb']

# %%
import pandas as pd

df = pd.read_csv("nassau.csv")

df.head()
# Out:
#    Row ID                      Order ID  Order Date   Ship Date  \
# 0       1  US-2021-103800-CHO-MIL-31000  03-01-2024  30-06-2026
# 1       2  US-2021-112326-CHO-TRI-54000  04-01-2024  01-07-2026
# 2       3  US-2021-112326-CHO-NUT-13000  04-01-2024  01-07-2026
# 3       4  US-2021-112326-CHO-SCR-58000  04-01-2024  01-07-2026
# 4       5  US-2021-141817-CHO-TRI-54000  05-01-2024  05-07-2026
#
#         Ship Mode  Customer ID Country/Region          City State/Province  \
# 0  Standard Class       103800  United States       Houston          Texas
# 1  Standard Class       112326  United States    Naperville       Illinois
# 2  Standard Class       112326  United States    Naperville       Illinois
# 3  Standard Class       112326  United States    Naperville       Illinois
# 4  Standard Class       141817  United States  Philadelphia   Pennsylvania
#
#   Postal Code   Division    Region     Product ID  \
# 0       77095  Chocolate  Interior  CHO-MIL-31000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          10194 non-null  int64
#  1   Order ID        10194 non-null  object
#  2   Order Date      10194 non-null  object
#  3   Ship Date       10194 non-null  object
#  4   Ship Mode       10194 non-null  object
#  5   Customer ID     10194 non-null  int64
#  6   Country/Region  10194 non-null  object
#  7   City            10194 non-null  object
#  8   State/Province  10194 non-null  object
#  9   Postal Code     10194 non-null  object
#  10  Division        10194 non-null  object
#  11  Region          10194 non-null  object
#  12  Product ID      10194 non-null  object
#  13  Product Name    10194 non-null  object
#  14  Sales           10194 non-null  float64
#  15  Units           10194 non-null  int64
#  16  Gross Profit    10194 non-null  float64
# ...

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], dayfirst=True)
df['Ship Date'] = pd.to_datetime(df['Ship Date'], dayfirst=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          10194 non-null  int64
#  1   Order ID        10194 non-null  object
#  2   Order Date      10194 non-null  datetime64[ns]
#  3   Ship Date       10194 non-null  datetime64[ns]
#  4   Ship Mode       10194 non-null  object
#  5   Customer ID     10194 non-null  int64
#  6   Country/Region  10194 non-null  object
#  7   City            10194 non-null  object
#  8   State/Province  10194 non-null  object
#  9   Postal Code     10194 non-null  object
#  10  Division        10194 non-null  object
#  11  Region          10194 non-null  object
#  12  Product ID      10194 non-null  object
#  13  Product Name    10194 non-null  object
#  14  Sales           10194 non-null  float64
#  15  Units           10194 non-null  int64
# ...

# %%
df['Lead_Time'] = (df['Ship Date'] - df['Order Date']).dt.days

df.head()
# Out:
#    Row ID                      Order ID Order Date  Ship Date       Ship Mode  \
# 0       1  US-2021-103800-CHO-MIL-31000 2024-01-03 2026-06-30  Standard Class
# 1       2  US-2021-112326-CHO-TRI-54000 2024-01-04 2026-07-01  Standard Class
# 2       3  US-2021-112326-CHO-NUT-13000 2024-01-04 2026-07-01  Standard Class
# 3       4  US-2021-112326-CHO-SCR-58000 2024-01-04 2026-07-01  Standard Class
# 4       5  US-2021-141817-CHO-TRI-54000 2024-01-05 2026-07-05  Standard Class
#
#    Customer ID Country/Region          City State/Province Postal Code  \
# 0       103800  United States       Houston          Texas       77095
# 1       112326  United States    Naperville       Illinois       60540
# 2       112326  United States    Naperville       Illinois       60540
# 3       112326  United States    Naperville       Illinois       60540
# 4       141817  United States  Philadelphia   Pennsylvania       19143
#
# ...

# %%
df['Lead_Time'].describe()
# Out:
# count    10194.000000
# mean      1320.841868
# std        262.444892
# min        904.000000
# 25%       1271.000000
# 50%       1274.000000
# 75%       1638.000000
# max       1642.000000
# Name: Lead_Time, dtype: float64

# %%
df = pd.read_csv("nassau.csv")

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df['Order Date'] = pd.to_datetime(df['Order Date'])
#       2 df['Ship Date'] = pd.to_datetime(df['Ship Date'])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1068, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1066             result = arg.tz_localize("utc")
#    1067 elif isinstance(arg, ABCSeries):
# -> 1068     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1069     if not cache_array.empty:
#    1070         result = arg.map(cache_array)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:249, in _maybe_cache(arg, format, cache, convert_listlike)
#     247 unique_dates = unique(arg)
#     248 if len(unique_dates) < len(arg):
# ...

# %%
df[['Order Date', 'Ship Date']].head(10)
# Out:
#    Order Date   Ship Date
# 0  03-01-2024  30-06-2026
# 1  04-01-2024  01-07-2026
# 2  04-01-2024  01-07-2026
# 3  04-01-2024  01-07-2026
# 4  05-01-2024  05-07-2026
# 5  06-01-2024  03-07-2026
# 6  06-01-2024  03-07-2026
# 7  06-01-2024  30-06-2026
# 8  06-01-2024  03-07-2026
# 9  06-01-2024  03-07-2026

# %%
df = pd.read_csv("nassau.csv")

df['Order Date'] = pd.to_datetime(df['Order Date'], dayfirst=True)
df['Ship Date'] = pd.to_datetime(df['Ship Date'], dayfirst=True)

# %%
df['Ship Date'] = df.apply(
    lambda row: row['Ship Date'].replace(year=row['Order Date'].year),
    axis=1
)

# %%
df['Lead_Time'] = (df['Ship Date'] - df['Order Date']).dt.days

# %%
df['Lead_Time'].describe()
# Out:
# count    10194.000000
# mean       -55.089759
# std        175.580008
# min       -192.000000
# 25%       -188.000000
# 50%       -186.000000
# 75%        177.000000
# max        182.000000
# Name: Lead_Time, dtype: float64

# %%
df = pd.read_csv("nassau.csv")

df['Order Date'] = pd.to_datetime(df['Order Date'], dayfirst=True)
df['Ship Date'] = pd.to_datetime(df['Ship Date'], dayfirst=True)

# %%
def correct_ship_date(row):
    order = row['Order Date']
    ship = row['Ship Date']
    
    # Replace ship year with order year
    ship = ship.replace(year=order.year)
    
    # If ship date is before order date, add 1 year
    if ship < order:
        ship = ship.replace(year=order.year + 1)
    
    return ship

df['Ship Date'] = df.apply(correct_ship_date, axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 14
#      10         ship = ship.replace(year=order.year + 1)
#      12     return ship
# ---> 14 df['Ship Date'] = df.apply(correct_ship_date, axis=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10401, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10387 from pandas.core.apply import frame_apply
#   10389 op = frame_apply(
#   10390     self,
#   10391     func=func,
#    (...)  10399     kwargs=kwargs,
#   10400 )
# > 10401 return op.apply().__finalize__(self, method="apply")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# ...

# %%
df['Ship Date'].dt.year.value_counts()
# Out:
# Ship Date
# 2029    2899
# 2028    2367
# 2030    2128
# 2027    2089
# 2026     711
# Name: count, dtype: int64

# %%
df = pd.read_csv("nassau.csv")

df['Order Date'] = pd.to_datetime(df['Order Date'], dayfirst=True)
df['Ship Date'] = pd.to_datetime(df['Ship Date'], dayfirst=True)

# %%
df['Ship_Adjusted'] = df['Ship Date'].apply(lambda x: x.replace(year=2024))

# %%
df['Lead_Time'] = (df['Ship_Adjusted'] - df['Order Date']).dt.days

# %%
df['Lead_Time'] = df['Lead_Time'].apply(lambda x: x if x >= 0 else x + 365)

# %%
df['Lead_Time'].describe()
# Out:
# count    10194.000000
# mean        42.247695
# std        176.382982
# min       -193.000000
# 25%       -187.000000
# 50%        176.000000
# 75%        178.000000
# max        185.000000
# Name: Lead_Time, dtype: float64

# %%
df = pd.read_csv("nassau.csv")

df['Order Date'] = pd.to_datetime(df['Order Date'], dayfirst=True)
df['Ship Date'] = pd.to_datetime(df['Ship Date'], dayfirst=True)

df['Lead_Time'] = (df['Ship Date'] - df['Order Date']).dt.days

# %%
factory_map = {
    "Wonka Bar - Nutty Crunch Surprise": "Lot's O' Nuts",
    "Wonka Bar - Fudge Mallows": "Lot's O' Nuts",
    "Wonka Bar -Scrumdiddlyumptious": "Lot's O' Nuts",
    "Wonka Bar - Milk Chocolate": "Wicked Choccy's",
    "Wonka Bar - Triple Dazzle Caramel": "Wicked Choccy's",
    "Laffy Taffy": "Sugar Shack",
    "SweeTARTS": "Sugar Shack",
    "Nerds": "Sugar Shack",
    "Fun Dip": "Sugar Shack",
    "Fizzy Lifting Drinks": "Sugar Shack",
    "Everlasting Gobstopper": "Secret Factory",
    "Hair Toffee": "The Other Factory",
    "Lickable Wallpaper": "Secret Factory",
    "Wonka Gum": "Secret Factory",
    "Kazookles": "The Other Factory"
}

df["Factory"] = df["Product Name"].map(factory_map)

# %%
df["Factory"].value_counts()
# Out:
# Factory
# Lot's O' Nuts        5692
# Wicked Choccy's      4152
# Secret Factory        217
# The Other Factory     100
# Sugar Shack            33
# Name: count, dtype: int64

# %%
df["Route_State"] = df["Factory"] + " → " + df["State/Province"]

# %%
df[["Factory", "State/Province", "Route_State"]].head()
# Out:
#            Factory State/Province                     Route_State
# 0  Wicked Choccy's          Texas         Wicked Choccy's → Texas
# 1  Wicked Choccy's       Illinois      Wicked Choccy's → Illinois
# 2    Lot's O' Nuts       Illinois        Lot's O' Nuts → Illinois
# 3    Lot's O' Nuts       Illinois        Lot's O' Nuts → Illinois
# 4  Wicked Choccy's   Pennsylvania  Wicked Choccy's → Pennsylvania

# %%
route_analysis = df.groupby("Route_State").agg(
    Total_Shipments=("Order ID", "count"),
    Avg_Lead_Time=("Lead_Time", "mean"),
    Lead_Time_STD=("Lead_Time", "std"),
    Total_Profit=("Gross Profit", "sum")
).reset_index()

route_analysis.head()
# Out:
#                         Route_State  Total_Shipments  Avg_Lead_Time  \
# 0           Lot's O' Nuts → Alabama               34    1295.205882
# 1           Lot's O' Nuts → Alberta               16    1273.875000
# 2           Lot's O' Nuts → Arizona              111    1306.198198
# 3          Lot's O' Nuts → Arkansas               31    1285.354839
# 4  Lot's O' Nuts → British Columbia               18    1273.777778
#
#    Lead_Time_STD  Total_Profit
# 0     253.070332        326.91
# 1     266.924428        141.42
# 2     253.901155       1013.15
# 3     274.529118        299.69
# 4     307.082774        173.80

# %%
# Total number of routes
len(route_analysis)

# Highest average lead time
route_analysis["Avg_Lead_Time"].max()

# Lowest average lead time
route_analysis["Avg_Lead_Time"].min()
# Out:
# 906.0

# %%
len(route_analysis)
# Out:
# 196

# %%
route_analysis["Avg_Lead_Time"].max()
# Out:
# 1642.0

# %%
route_analysis["Avg_Lead_Time"].min()
# Out:
# 906.0

# %%
top_10 = route_analysis.sort_values("Avg_Lead_Time").head(10)
top_10
# Out:
#                          Route_State  Total_Shipments  Avg_Lead_Time  \
# 76         Secret Factory → Nebraska                1          906.0
# 80       Secret Factory → New Mexico                2          906.0
# 121    The Other Factory → Louisiana                1          907.0
# 115  The Other Factory → Connecticut                2          907.5
# 158          Wicked Choccy's → Maine                2          908.0
# 75      Secret Factory → Mississippi                1          908.0
# 70        Secret Factory → Louisiana                2          908.5
# 64         Secret Factory → Delaware                1          909.0
# 88   Secret Factory → South Carolina                1          909.0
# 74        Secret Factory → Minnesota                1          909.0
#
#      Lead_Time_STD  Total_Profit
# 76             NaN          1.30
# 80        2.828427          6.50
# 121            NaN          0.75
# 115       2.121320          0.75
# 158       0.000000         36.07
# ...

# %%
bottom_10 = route_analysis.sort_values("Avg_Lead_Time", ascending=False).head(10)
bottom_10
# Out:
#                          Route_State  Total_Shipments  Avg_Lead_Time  \
# 103         Sugar Shack → New Jersey                1         1642.0
# 78    Secret Factory → New Hampshire                1         1641.0
# 98         Sugar Shack → Connecticut                1         1641.0
# 194  Wicked Choccy's → West Virginia                2         1639.0
# 37      Lot's O' Nuts → North Dakota                5         1638.2
# 97          Sugar Shack → California                1         1638.0
# 110         Sugar Shack → Washington                1         1638.0
# 63      Secret Factory → Connecticut                1         1638.0
# 125       The Other Factory → Nevada                1         1638.0
# 105               Sugar Shack → Ohio                2         1637.5
#
#      Lead_Time_STD  Total_Profit
# 103            NaN          3.72
# 78             NaN          3.25
# 98             NaN          2.48
# 194       0.000000         16.47
# 37        1.643168         39.66
# ...

# %%
route_analysis["Efficiency_Score"] = (
    (route_analysis["Avg_Lead_Time"].max() - route_analysis["Avg_Lead_Time"]) /
    (route_analysis["Avg_Lead_Time"].max() - route_analysis["Avg_Lead_Time"].min())
)

# %%
route_analysis.head()
# Out:
#                         Route_State  Total_Shipments  Avg_Lead_Time  \
# 0           Lot's O' Nuts → Alabama               34    1295.205882
# 1           Lot's O' Nuts → Alberta               16    1273.875000
# 2           Lot's O' Nuts → Arizona              111    1306.198198
# 3          Lot's O' Nuts → Arkansas               31    1285.354839
# 4  Lot's O' Nuts → British Columbia               18    1273.777778
#
#    Lead_Time_STD  Total_Profit  Efficiency_Score
# 0     253.070332        326.91          0.471188
# 1     266.924428        141.42          0.500170
# 2     253.901155       1013.15          0.456252
# 3     274.529118        299.69          0.484572
# 4     307.082774        173.80          0.500302

# %%
region_analysis = df.groupby("Region").agg(
    Avg_Lead_Time=("Lead_Time", "mean"),
    Total_Shipments=("Order ID", "count"),
    Total_Profit=("Gross Profit", "sum")
).reset_index()

region_analysis
# Out:
#      Region  Avg_Lead_Time  Total_Shipments  Total_Profit
# 0  Atlantic    1322.745144             2986      26973.70
# 1      Gulf    1311.374691             1620      14700.67
# 2  Interior    1323.091221             2335      21282.49
# 3   Pacific    1322.194897             3253      30485.94

# %%
ship_mode_analysis = df.groupby("Ship Mode").agg(
    Avg_Lead_Time=("Lead_Time", "mean"),
    Total_Shipments=("Order ID", "count"),
    Total_Profit=("Gross Profit", "sum")
).reset_index()

ship_mode_analysis
# Out:
#         Ship Mode  Avg_Lead_Time  Total_Shipments  Total_Profit
# 0     First Class    1338.275840             1548      14011.09
# 1        Same Day    1333.442413              547       4700.73
# 2    Second Class    1323.845376             1979      18306.52
# 3  Standard Class    1314.334641             6120      56424.46

# %%
overall_avg = df["Lead_Time"].mean()
overall_avg
# Out:
# np.float64(1320.8418677653522)

# %%
df["Delayed"] = df["Lead_Time"] > 1320.8418677653522

# %%
delay_rate = df["Delayed"].mean() * 100
delay_rate
# Out:
# np.float64(33.14694918579556)

# %%
state_analysis = df.groupby("State/Province").agg(
    Avg_Lead_Time=("Lead_Time", "mean"),
    Total_Shipments=("Order ID", "count"),
    Total_Profit=("Gross Profit", "sum")
).reset_index()

state_analysis.sort_values("Avg_Lead_Time", ascending=False).head(10)
# Out:
#           State/Province  Avg_Lead_Time  Total_Shipments  Total_Profit
# 56         West Virginia    1638.000000                4         43.89
# 37          North Dakota    1637.857143                7         73.96
# 47          Saskatchewan    1457.000000                2         18.99
# 20              Manitoba    1455.333333               12         90.27
# 15                  Iowa    1443.900000               30        269.97
# 33            New Mexico    1441.837838               37        335.17
# 53               Vermont    1438.909091               11        109.98
# 44  Prince Edward Island    1420.300000               10         88.66
# 49          South Dakota    1395.916667               12        104.14
# 50             Tennessee    1391.486339              183       1573.52

# %%
top_10 = route_analysis.sort_values("Avg_Lead_Time").head(10)

# %%
plt.figure(figsize=(10,6))

sns.barplot(
    data=top_10,
    x="Avg_Lead_Time",
    y="Route_State",
    hue="Route_State",
    palette="Greens_r",
    legend=False
)

plt.title("Top 10 Most Efficient Routes (Lowest Lead Time)")
plt.xlabel("Average Lead Time")
plt.ylabel("Route")
plt.show()

# %%
plt.figure(figsize=(10,6))

sns.barplot(
    data=bottom_10,
    x="Avg_Lead_Time",
    y="Route_State",
    hue="Route_State",
    palette="Reds",
    legend=False
)

plt.title("Bottom 10 Least Efficient Routes (Highest Lead Time)")
plt.xlabel("Average Lead Time")
plt.ylabel("Route")
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    data=region_analysis,
    x="Region",
    y="Avg_Lead_Time",
    hue="Region",
    palette="Blues",
    legend=False
)

plt.title("Average Lead Time by Region")
plt.xlabel("Region")
plt.ylabel("Average Lead Time")
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    data=ship_mode_analysis,
    x="Ship Mode",
    y="Avg_Lead_Time",
    hue="Ship Mode",
    palette="Oranges",
    legend=False
)

plt.title("Average Lead Time by Ship Mode")
plt.xlabel("Ship Mode")
plt.ylabel("Average Lead Time")
plt.xticks(rotation=45)
plt.show()

# %%
top_states = state_analysis.sort_values("Avg_Lead_Time", ascending=False).head(10)

plt.figure(figsize=(10,6))

sns.barplot(
    data=top_states,
    x="Avg_Lead_Time",
    y="State/Province",
    hue="State/Province",
    palette="Purples",
    legend=False
)

plt.title("Top 10 High-Delay States")
plt.xlabel("Average Lead Time")
plt.ylabel("State")
plt.show()

# %%
df["Route_Region"] = df["Factory"] + " → " + df["Region"]

# %%
route_region_analysis = df.groupby("Route_Region").agg(
    Total_Shipments=("Order ID", "count"),
    Avg_Lead_Time=("Lead_Time", "mean"),
    Total_Profit=("Gross Profit", "sum")
).reset_index()

route_region_analysis.head()
# Out:
#                 Route_Region  Total_Shipments  Avg_Lead_Time  Total_Profit
# 0   Lot's O' Nuts → Atlantic             1661    1326.825406      15315.63
# 1       Lot's O' Nuts → Gulf              897    1313.975474       8313.42
# 2   Lot's O' Nuts → Interior             1321    1324.196064      12353.56
# 3    Lot's O' Nuts → Pacific             1813    1317.527854      16788.44
# 4  Secret Factory → Atlantic               72    1349.250000       1499.85

# %%
len(route_region_analysis)
# Out:
# 20

# %%
cost_time_analysis
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 cost_time_analysis
#
# NameError: name 'cost_time_analysis' is not defined

# %%
cost_time_analysis = df.groupby("Ship Mode").agg(
    Avg_Lead_Time=("Lead_Time", "mean"),
    Avg_Cost=("Cost", "mean"),
    Avg_Profit=("Gross Profit", "mean")
).reset_index()

cost_time_analysis
# Out:
#         Ship Mode  Avg_Lead_Time  Avg_Cost  Avg_Profit
# 0     First Class    1338.275840  4.721124    9.051092
# 1        Same Day    1333.442413  4.411225    8.593656
# 2    Second Class    1323.845376  4.827539    9.250389
# 3  Standard Class    1314.334641  4.749328    9.219683

# %%
df["Lead_Time"].describe()
# Out:
# count    10194.000000
# mean      1320.841868
# std        262.444892
# min        904.000000
# 25%       1271.000000
# 50%       1274.000000
# 75%       1638.000000
# max       1642.000000
# Name: Lead_Time, dtype: float64
